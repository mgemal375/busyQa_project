# %% [markdown]
# <a href="https://colab.research.google.com/github/mgemal375/busyQa_project/blob/main/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
df = pd.read_csv("predictive_maintenance.csv")
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.dtypes
# Out:
# UDI                          int64
# Product ID                  object
# Type                        object
# Air temperature [K]        float64
# Process temperature [K]    float64
# Rotational speed [rpm]       int64
# Torque [Nm]                float64
# Tool wear [min]              int64
# Target                       int64
# Failure Type                object
# dtype: object

# %%
cat_cols=[]
num_cols=[]
num_cols=df.select_dtypes(include=[np.number]).columns
cat_cols = df.select_dtypes(include=['object']).columns
print("Categorical columns are :-")
print(cat_cols)
print("Numerical Columns are :-")
print(num_cols)
# Out:
# Categorical columns are :-
# Index(['Product ID', 'Type', 'Failure Type'], dtype='object')
# Numerical Columns are :-
# Index(['UDI', 'Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Target'],
#       dtype='object')

# %%
len(df.loc[df["Failure Type"]=="No Failure"])
# Out:
# 9652

# %%
plt.hist(df["Failure Type"], bins=10)  # You can adjust the number of bins
plt.title('Histogram')
plt.xlabel('Data Values')
plt.xticks(rotation="vertical")
plt.ylabel('Frequency')
plt.show()

# %%
# Out:
# array([0, 1])

# %%
df_0=df.loc[df.Target == 0]
df_0
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %%
df_1=df_0.loc[df_0["Failure Type"]!="No Failure"]
df_1
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 1221  1222     M16081    M                297.0                    308.3
# 1302  1303     L48482    L                298.6                    309.8
# 1748  1749     H31162    H                298.4                    307.7
# 2072  2073     L49252    L                299.6                    309.5
# 2559  2560     L49739    L                299.3                    309.0
# 3065  3066     M17925    M                300.1                    309.2
# 3452  3453     H32866    H                301.6                    310.5
# 5471  5472     L52651    L                302.7                    312.3
# 5489  5490     L52669    L                302.6                    312.1
# 5495  5496     H34909    H                302.9                    312.5
# 5509  5510     L52689    L                302.8                    312.2
# 5553  5554     L52733    L                302.5                    311.9
# ...
